# %%
import pandas as pd
import redis
import threading
import multiprocessing

from cryptofeed.feedhandler import FeedHandler
from cryptofeed import exchanges
from cryptofeed.defines import TRADES, L2_BOOK, BID, ASK, TICKER

from algos.daddy.bot import daddy_bot, daddy_trade, daddy_book, daddy_ticker
from main import initial_tasks


f = FeedHandler(retries=100000)

EXCHANGES = pd.read_csv('algos/daddy/exchanges.csv')
EXCHANGES = EXCHANGES.drop_duplicates(subset=['exchange'])
EXCHANGES = EXCHANGES.fillna("")
# Out:
# BITMEX_ID
# BITMEX_SECRET
# Position Set
# BITMEX_2_ID
# BITMEX_2_SECRET
# Position Set
# BITMEX_3_ID
# BITMEX_3_SECRET
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ef83ba8cfff8> in <module>
#       8 from cryptofeed.defines import TRADES, L2_BOOK, BID, ASK, TICKER
#       9
# ---> 10 from algos.daddy.bot import daddy_bot, daddy_trade, daddy_book, daddy_ticker
#      11 from main import initial_tasks
#      12
#
# ~/Desktop/Projects/algorithms/algos/daddy/bot.py in <module>
#      36
#      37     if details['trade'] == 1 or exchange_name == 'bitmex':
# ---> 38         lts[name] = liveTrading(exchange_name, name, symbol=details['ccxt_symbol'],testnet=TESTNET)
#      39         lts[name].set_position()
#      40         print("Position Set")
#
# ~/Desktop/Projects/algorithms/algos/daddy/live_trader.py in __init__(self, exchange, name, symbol, testnet)
#     159
#     160         self.r = redis.Redis(host='localhost', port=6379, db=0)
# --> 161         self.update_parameters()
#     162
#     163     def update_parameters(self):
#
# ~/Desktop/Projects/algorithms/algos/daddy/live_trader.py in update_parameters(self)
#     169             try:
#     170                 if self.exchange_name == 'bitmex':
# --> 171                     stats = self.exchange.private_post_position_leverage({"symbol": self.symbol_here, "leverage": str(self.lev)})
#     172                     break
#     173                 elif self.exchange_name == 'binance_futures':
#
# ~/.local/lib/python3.8/site-packages/ccxt/base/exchange.py in inner(_self, params)
#     463                             if params is not None:
#     464                                 inner_kwargs['params'] = params
# --> 465                             return entry(_self, **inner_kwargs)
#     466                         return inner
#     467                     to_bind = partialer()
#
# ~/.local/lib/python3.8/site-packages/ccxt/base/exchange.py in request(self, path, api, method, params, headers, body)
#     488     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#     489         """Exchange.request is the entry point for all generated methods"""
# --> 490         return self.fetch2(path, api, method, params, headers, body)
#     491
#     492     @staticmethod
#
# ~/.local/lib/python3.8/site-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     484         self.lastRestRequestTimestamp = self.milliseconds()
#     485         request = self.sign(path, api, method, params, headers, body)
# --> 486         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     487
#     488     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~/.local/lib/python3.8/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     560         json_response = None
#     561         try:
# --> 562             response = self.session.request(
#     563                 method,
#     564                 url,
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     514             hooks=hooks,
#     515         )
# --> 516         prep = self.prepare_request(req)
#     517
#     518         proxies = proxies or {}
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in prepare_request(self, request)
#     453             data=request.data,
#     454             json=request.json,
# --> 455             headers=merge_setting(request.headers, self.headers, dict_class=CaseInsensitiveDict),
#     456             params=merge_setting(request.params, self.params),
#     457             auth=merge_setting(auth, self.auth),
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in merge_setting(request_setting, session_setting, dict_class)
#      67         return request_setting
#      68
# ---> 69     merged_setting = dict_class(to_key_val_list(session_setting))
#      70     merged_setting.update(to_key_val_list(request_setting))
#      71
#
# ~/.local/lib/python3.8/site-packages/requests/utils.py in to_key_val_list(value)
#     311         value = value.items()
#     312
# --> 313     return list(value)
#     314
#     315
#
# /usr/lib/python3.8/_collections_abc.py in __iter__(self)
#     742     def __iter__(self):
#     743         for key in self._mapping:
# --> 744             yield (key, self._mapping[key])
#     745
#     746 ItemsView.register(dict_items)
#
# ~/.local/lib/python3.8/site-packages/requests/structures.py in __getitem__(self, key)
#      52
#      53     def __getitem__(self, key):
# ---> 54         return self._store[key.lower()][1]
#      55
#      56     def __delitem__(self, key):
#
# KeyboardInterrupt:
