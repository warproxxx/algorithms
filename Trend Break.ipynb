# %%
from algos.daddy.trades import get_trends
import pandas as pd

# %%
trends = get_trends()
# Out:
# /home/warproxxx/Desktop/Projects/algorithms/algos/daddy/trades.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row['curr_group'] = curr_group
# /home/warproxxx/.local/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
trends
# Out:
#      30D_volatility    close curr_group  timestamp
# 0         65.865040   7179.0 2020-01-02 2020-01-02
# 1         65.865040   6942.0 2020-01-02 2020-01-03
# 2         65.865040   7335.0 2020-01-02 2020-01-04
# 3         65.865040   7345.0 2020-01-02 2020-01-05
# 4         65.865040   7350.5 2020-01-02 2020-01-06
# ..              ...      ...        ...        ...
# 381      624.070426  36007.0 2021-01-15 2021-01-17
# 382      614.949982  35870.0 2021-01-15 2021-01-18
# 383      605.257634  36684.5 2021-01-15 2021-01-19
# 384      593.412016  35898.0 2021-01-15 2021-01-20
# 385      577.439635  35489.0 2021-01-15 2021-01-21
#
# [386 rows x 4 columns]

# %%
pd.read_csv("data/btc_daily.csv")
# Out:
#       timestamp  symbol     open     high      low    close  trades  \
# 0    2020-01-01  XBTUSD   7218.5   7298.5   7115.0   7163.0  352988
# 1    2020-01-02  XBTUSD   7163.0   7234.5   7153.0   7179.0  274470
# 2    2020-01-03  XBTUSD   7179.0   7183.0   6905.5   6942.0  425292
# 3    2020-01-04  XBTUSD   6942.0   7412.0   6855.0   7335.0  751545
# 4    2020-01-05  XBTUSD   7335.0   7399.0   7258.5   7345.0  368114
# ..          ...     ...      ...      ...      ...      ...     ...
# 382  2021-01-17  XBTUSD  36734.5  37969.5  35420.5  36007.0  433918
# 383  2021-01-18  XBTUSD  36007.0  36852.5  33862.0  35870.0  417991
# 384  2021-01-19  XBTUSD  35870.0  37533.5  34774.5  36684.5  360343
# 385  2021-01-20  XBTUSD  36684.5  37920.0  35810.5  35898.0  372084
# 386  2021-01-21  XBTUSD  35898.0  36381.5  33333.0  35489.0  427275
#
#          volume        vwap  lastSize        turnover   homeNotional  \
# 0    1097785557   7201.4979      1500  15244748390818  152447.483908
# ...

# %%
trends.iloc[-2]['curr_group'] != trends.iloc[-1]['curr_group']
# Out:
# False
